# %%
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
# Import data here
df=pd.read_csv("../datasets/Labeled/train_dataset.csv", header=None)
df_test=pd.read_csv("../datasets/Labeled/test_dataset.csv", header=None)
df.head()
# Out:
#        0                   1                   2                    3   \
# 0  Socket      Execution Time               Power              Current
# 1    rpi3  109.77205580699956   3.909131578947368  0.04947368421052632
# 2    rpi4   6.252172244999997               3.726                0.048
# 3    rpi4   5.413318097000001                3.77                0.048
# 4    rpi4   6.159591703000046  3.7439999999999998                0.043
#
#                    4                   5                   6           7   \
# 0             Voltage              Memory           CPU Usage  Read Bytes
# 1  116.67165789473684   320.1236324310303   99.99812720370008   325058953
# 2             116.178    320.122727394104   99.96525615554296   325059001
# 3             115.747   320.0559024810791   99.75397534818109   325059001
# 4             116.004  320.02650260925293  100.00662863741042   325058998
#
#             8          9   ...     11             12         13  \
# 0  Write Bytes  Signature  ...   Size  Avg File Size  CPU Count
# 1            0     207030  ...  310.0           62.0          4
# 2            0     207030  ...  310.0           62.0          4
# 3            0      92160  ...  310.0           62.0          4
# 4            0      23135  ...  310.0           62.0          4
#
#               14             15          16             17  \
# 0      Total RAM  Available RAM  System CPU  System Memory
# 1   923.20703125      730.96875         0.5           20.8
# 2  7812.31640625   7118.9453125         0.0            9.2
# 3  7812.31640625   7118.9453125         0.0            9.1
# 4  7812.31640625   7118.9453125         0.0            9.2
#
#                    18                  19                   20
# 0       Time Per File          Throughput            Algorithm
# 1   21.94864715499989  2.8247754662125697  cross-rsdp-192-fast
# 2   1.248899219399982   49.64371747288554  cross-rsdp-192-fast
# 3  1.0811231009999802  57.347770982465704  cross-rsdp-128-fast
# 4  1.2303292149999607  50.393016148935374            ML-DSA-87
#
# [5 rows x 21 columns]

# %%
df.columns = df.iloc[0]
df_test.columns = df_test.iloc[0]
df = df[1:]
df_test = df_test[1:]
df.head()
# Out:
# 0 Socket      Execution Time               Power              Current  \
# 1   rpi3  109.77205580699956   3.909131578947368  0.04947368421052632
# 2   rpi4   6.252172244999997               3.726                0.048
# 3   rpi4   5.413318097000001                3.77                0.048
# 4   rpi4   6.159591703000046  3.7439999999999998                0.043
# 5   rpi3    46.0946591930001   3.946533333333333  0.05013333333333335
#
# 0             Voltage              Memory           CPU Usage Read Bytes  \
# 1  116.67165789473684   320.1236324310303   99.99812720370008  325058953
# 2             116.178    320.122727394104   99.96525615554296  325059001
# 3             115.747   320.0559024810791   99.75397534818109  325059001
# 4             116.004  320.02650260925293  100.00662863741042  325058998
# 5  116.19699999999999  320.10715198516846   99.96819763231404  325058952
#
# 0 Write Bytes Signature  ...   Size Avg File Size CPU Count      Total RAM  \
# 1           0    207030  ...  310.0          62.0         4   923.20703125
# 2           0    207030  ...  310.0          62.0         4  7812.31640625
# 3           0     92160  ...  310.0          62.0         4  7812.31640625
# 4           0     23135  ...  310.0          62.0         4  7812.31640625
# 5           0    178320  ...  310.0          62.0         4   923.20703125
#
# 0 Available RAM System CPU System Memory       Time Per File  \
# 1     730.96875        0.5          20.8   21.94864715499989
# 2  7118.9453125        0.0           9.2   1.248899219399982
# 3  7118.9453125        0.0           9.1  1.0811231009999802
# 4  7118.9453125        0.0           9.2  1.2303292149999607
# 5     730.96875        0.0          20.7        9.2097393948
#
# 0          Throughput               Algorithm
# 1  2.8247754662125697     cross-rsdp-192-fast
# 2   49.64371747288554     cross-rsdp-192-fast
# 3  57.347770982465704     cross-rsdp-128-fast
# 4  50.393016148935374               ML-DSA-87
# 5  6.7320037345471935  SLH_DSA_PURE_SHA2_192F
#
# [5 rows x 21 columns]

# %%
# Feature selection
X_train = df.drop(['Algorithm'], axis=1)
y_train = df['Algorithm']
X_test = df_test.drop(['Algorithm'], axis=1)
y_test = df_test['Algorithm']

# Ensure consistent data types
string_cols_train = X_train.columns[X_train.columns != 'Socket']
X_train[string_cols_train] = X_train[string_cols_train].astype(float)
string_cols_test = X_test.columns[X_test.columns != 'Socket']
X_test[string_cols_test] = X_test[string_cols_test].astype(float)

# Align test features with training features
X_test = X_test.reindex(columns=X_train.columns, fill_value=0)

# %%
# Split data

object_cols = [col for col in X_train.columns if X_train[col].dtype == "object"]
low_cardinality_cols = [col for col in object_cols if X_train[col].nunique() < 10]
high_cardinality_cols = list(set(object_cols)-set(low_cardinality_cols))
low_cardinality_cols
# Out:
# ['Socket']

# %%
num_X_train = X_train.select_dtypes(exclude=['object'])
num_X_test = X_test.select_dtypes(exclude=['object'])

OH_cols_train = pd.get_dummies(X_train[low_cardinality_cols],drop_first=False)
OH_cols_test = pd.get_dummies(X_test[low_cardinality_cols],drop_first=False)

X_train = pd.concat([num_X_train, OH_cols_train], axis=1)
X_test = pd.concat([num_X_test, OH_cols_test], axis=1)

# %%
knn = KNeighborsClassifier(n_neighbors=18, weights='distance') # optimize the n_neighbors value
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=18, weights='distance')

# %%
y_predict = knn.predict(X_test)
y_predict
# Out:
# array(['SLH_DSA_PURE_SHA2_192F', 'MAYO-2', 'cross-rsdp-256-small',
#        'cross-rsdp-128-balanced', 'cross-rsdp-192-small',
#        'SLH_DSA_PURE_SHA2_128F', 'SLH_DSA_PURE_SHA2_128F',
#        'SLH_DSA_PURE_SHAKE_256F', 'MAYO-1', 'SLH_DSA_PURE_SHAKE_128F',
#        'cross-rsdp-256-fast', 'Falcon-512', 'OV-III', 'OV-V',
#        'SNOVA_24_5_4', 'Falcon-512', 'SNOVA_56_25_2',
#        'cross-rsdp-256-balanced', 'SLH_DSA_PURE_SHA2_256F', 'ML-DSA-87',
#        'cross-rsdp-128-fast', 'cross-rsdp-256-balanced',
#        'SLH_DSA_PURE_SHA2_192F', 'Falcon-512', 'Falcon-512',
#        'SNOVA_24_5_4', 'SLH_DSA_PURE_SHAKE_128F',
#        'SLH_DSA_PURE_SHA2_256F', 'ML-DSA-65', 'ML-DSA-87',
#        'cross-rsdp-128-balanced', 'SNOVA_24_5_4',
#        'SLH_DSA_PURE_SHA2_256F', 'cross-rsdp-256-small', 'Falcon-1024',
#        'cross-rsdp-192-small', 'cross-rsdp-192-fast', 'ML-DSA-65',
#        'SLH_DSA_PURE_SHAKE_192F', 'SPHINCS+-SHA2-256f-simple',
#        'cross-rsdp-256-fast', 'cross-rsdp-192-small', 'ML-DSA-44',
#        'SPHINCS+-SHA2-128f-simple', 'ML-DSA-44', 'MAYO-2', 'MAYO-5',
#        'SPHINCS+-SHA2-128f-simple', 'cross-rsdp-128-small',
#        'cross-rsdp-128-small', 'cross-rsdp-128-fast', 'MAYO-3', 'MAYO-5',
#        'SNOVA_56_25_2', 'SLH_DSA_PURE_SHA2_256F', 'SNOVA_60_10_4',
#        'OV-Is', 'cross-rsdp-192-balanced', 'MAYO-1', 'MAYO-2',
#        'Falcon-1024', 'OV-Is', 'SPHINCS+-SHA2-192f-simple',
#        'cross-rsdp-192-fast', 'SLH_DSA_PURE_SHAKE_192F',
#        'SLH_DSA_PURE_SHA2_192F'], dtype=object)

# %%
# Accuracy
print("Accuracy of K Nearest Neighbors model is ", metrics.accuracy_score(y_test, y_predict))
print("F1 Score is ", metrics.f1_score(y_predict, y_test, average="weighted"))
# Out:
# Accuracy of K Nearest Neighbors model is  0.8636363636363636
# F1 Score is  0.8727272727272728

# %%
# Confusion matrix
# labels = ["cipher1", "cipher2", ...]
cm = metrics.confusion_matrix(y_test, y_predict)
display = metrics.ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=knn.classes_)
display.plot(xticks_rotation='vertical')

# %%
# ROC curve
from sklearn.preprocessing import label_binarize
import numpy as np

y_scores = knn.predict_proba(X_test)
y_test_bin = label_binarize(y_test, classes=np.unique(y_test))

fpr = dict()
tpr = dict()
roc_auc = dict()
n_classes = y_test_bin.shape[1]

for i in range(n_classes):
    fpr[i], tpr[i], _ = metrics.roc_curve(y_test_bin[:, i], y_scores[:, 1])
    roc_auc[i] = metrics.auc(fpr[i], tpr[i])

# %%
# Plot the ROC curve for each class

import matplotlib.pyplot as plt
plt.figure()
classes = knn.classes_
colors = ['blue', 'red', 'green', 'cyan', 'magenta', 'yellow', 'black', 'orange', 'purple']
for i, cur_class, color in zip(range(n_classes), classes, colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=2,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(cur_class, roc_auc[i]))

plt.plot([0, 1], [0, 1], "k--", lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Receiver Operating Characteristic (ROC) Curve for Decision Tree")
plt.legend(loc="lower right")
plt.show()

# %%
from sklearn.metrics import roc_curve, auc
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import label_binarize

model = knn
y_scores = model.predict_proba(X_test)
y_test_bin = label_binarize(y_test, classes=np.unique(y_test))

fpr = dict()
tpr = dict()
roc_auc = dict()
n_classes = y_test_bin.shape[1]


for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test_bin[:, i], y_scores[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot the ROC curve for each class
plt.figure()
classes = model.classes_
colors = ['blue', 'red', 'green', 'cyan', 'magenta', 'yellow', 'black', 'orange', 'purple']
for i, cur_class, color in zip(range(n_classes), classes, colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=2,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(cur_class, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve for Naive-Bayes')
plt.legend(loc="lower right")
plt.show()

# %%
from joblib import dump

dump(knn, 'knn.joblib')
# Out:
# ['knn.joblib']
